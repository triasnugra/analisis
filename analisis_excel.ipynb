# %% [markdown]
# <a href="https://colab.research.google.com/github/triasnugra/analisis/blob/main/analisis_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library openpyxl jika belum terpasang
# !pip install openpyxl

import openpyxl
from google.colab import files

# Unggah file Excel
uploaded = files.upload()

# Ambil nama file yang diunggah
file_path = list(uploaded.keys())[0]

# Load workbook
workbook = openpyxl.load_workbook(file_path)
sheet = workbook.active

# Kode warna kuning yang ditemukan (FFFFFF00)
yellow_cells_text = []

for row in sheet.iter_rows():
    for cell in row:
        # Cek jika sel memiliki fill dan fill color RGB-nya kuning (FFFFFF00)
        if cell.fill.start_color.index == 'FFFFFF00':
            yellow_cells_text.append(cell.value)

# Menampilkan hasil
print("Teks dari sel dengan background kuning:")
for text in yellow_cells_text:
    print(text)
# Out:
# ...
#      <input type="file" id="files-ff2c0a3d-d326-462f-9f13-3ff4932b37d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff2c0a3d-d326-462f-9f13-3ff4932b37d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install library pandas jika belum terpasang
# !pip install pandas

import pandas as pd
import re

# Ambil output dari cell sebelumnya (misalnya, hasil output yang sudah ada)
output_text = """
HASIL PEMETAAN ASESMEN AWAL SISWA
tidak dipetakan, hanya kesimpulan
TUJUAN PEMBELAJARAN:
terdapat tujuan pembelajaran harian, apakah ini maksudnya ATP?
URUTAN KEGIATAN PEMBELAJARAN
terdapat muatan inovatif, P5 ditambahi kompetensi lain sendiri
pada kegiatan inti tidak menghadirkankegiatan dengan makanan asli
POKOK MATERI
tidak sesuai dengan tujuan pembelajaran pada modul ajar yang dibuat
tidak ada TFP hanya judul
PENGERTIAN
FUNGSI MAKANAN DAN MINUMAN
ASAL MAKANANAN DAN MINUMAN
ADAB MAKAN DAN MINUM
HIDUP
SEHAT
K3
MANFAAT MAKANAN DAN MINUMAN SEHAT
CURAH IDE KEGIATAN
2 subjudul dari konsep tidak ada di kegiatan main
RENCANA PEMBELAJARAN
antara alat dan bahan dengan kegiatan inti kurang dijelaskan bagaimana penggunaannya
topik lingkungan sekolah tapi kurang maksimal penggunakan bendi di sekitar sekolah
PERANGKAT PEMBELAJARAN
tujuan pembelajaran sangat tidak maksimal tentang tanaman/buah & materi sangat sedikit
RENCANA PELAKSANAAN PEMBELAJARAN HARIAN
kegiatan inti tidak nyambung dengan tujuan pembelajaran
kegiatan inti terdapat "Duniawi" ini maksudnya apa
TUJUAN PEMBELAJARAN
Tujuan pembelajaran kurang beriringan dengan CP STEAM
PEMAHAMAN BERMAKNA
PERTANYAAN PEMANTIK
RENCANA ASESMEN
HASIL PEMETAAN ASESMEN AWAL PESERTA DIDIK
setiap kelas mengapa dibedakan asesmennya
LANGKAH-LANGKAH PEMBELAJARAN
kegiatan mengapa hanya mengulangi hasil dari pemetaan awal
ASESMEN hanya ceklis dan hasil karya
URUTAN KEGIATAN PEMBELAJARAN
terdapat muatan inovatif, P5 ditambahi kompetensi lain sendiri
pada kegiatan inti tidak menghadirkankegiatan dengan buah asli namun ada pewarna dari bahan asli
REFLEKSI, PENGAYAAN, KOMPONEN LAIN, REMEDIAL, DAN REFERENSI
refleksi guru tidak dijawab
IDENTITAS DAN INFORMASI UMUM
elemen yang dimuat hanya literasi dan sains
HASIL PEMETAAN ASESMEN AWAL PESERTA DIDIK
tidak ada asesmen
"""

# Pisahkan teks menjadi kalimat-kalimat (menggunakan tanda baca sebagai pemisah)
text_list = re.split(r'\n+', output_text.strip())  # Menggunakan \n untuk memisahkan kalimat berdasarkan baris

# Menghitung jumlah kemunculan kalimat yang sama
kalimat_counts = pd.Series(text_list).value_counts().reset_index()
kalimat_counts.columns = ['Kalimat', 'Frekuensi']

# Menampilkan tabel hasil dengan pengaturan tampilan maksimal
pd.set_option('display.max_rows', None)  # Menampilkan semua baris dalam tabel tanpa terpotong
print("Tabel pengelompokan kalimat:")
print(kalimat_counts)

# Simpan hasil tabel ke file Excel
kalimat_counts.to_excel("hasil_pengelompokan_kalimat.xlsx", index=False)
print("Tabel pengelompokan kalimat telah disimpan sebagai 'hasil_pengelompokan_kalimat.xlsx'")
# Out:
# ...
# Tabel pengelompokan kalimat:
#                                                Kalimat  Frekuensi
# 0                                          PETA KONSEP          9
# 1                                     tidak ada materi          7
# 2                                        KOMPONEN INTI          6
# 3                     RENCANA PELAKSANAAN PEMBELAJARAN          6
# 4            HASIL PEMETAAN ASESMEN AWAL PESERTA DIDIK          5
# 5                                   CURAH IDE KEGIATAN          5
# 6                         LANGKAH-LANGKAH PEMBELAJARAN          5
# 7                         URUTAN KEGIATAN PEMBELAJARAN          5
# 8                                 tidak ada materi tfp          4
# 9                                              ASESMEN          4
# 10                        IDENTITAS DAN INFORMASI UMUM          4
# 11                                   tidak ada asesmen          3
# 12                                     CATATAN ANEKDOT          3
# ...

# %%
from google.colab import files
files.download('hasil_pengelompokan_kalimat.xlsx')

# %%
# Install library yang diperlukan
# !pip install pandas matplotlib

import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt

# Ambil output dari cell sebelumnya (misalnya, hasil output yang sudah ada)
output_text = """
HASIL PEMETAAN ASESMEN AWAL SISWA
tidak dipetakan, hanya kesimpulan
TUJUAN PEMBELAJARAN:
terdapat tujuan pembelajaran harian, apakah ini maksudnya ATP?
URUTAN KEGIATAN PEMBELAJARAN
terdapat muatan inovatif, P5 ditambahi kompetensi lain sendiri
pada kegiatan inti tidak menghadirkankegiatan dengan makanan asli
POKOK MATERI
tidak sesuai dengan tujuan pembelajaran pada modul ajar yang dibuat
tidak ada TFP hanya judul
PENGERTIAN
FUNGSI MAKANAN DAN MINUMAN
ASAL MAKANANAN DAN MINUMAN
ADAB MAKAN DAN MINUM
HIDUP
SEHAT
K3
MANFAAT MAKANAN DAN MINUMAN SEHAT
CURAH IDE KEGIATAN
2 subjudul dari konsep tidak ada di kegiatan main
RENCANA PEMBELAJARAN
antara alat dan bahan dengan kegiatan inti kurang dijelaskan bagaimana penggunaannya
topik lingkungan sekolah tapi kurang maksimal penggunakan bendi di sekitar sekolah
PERANGKAT PEMBELAJARAN
tujuan pembelajaran sangat tidak maksimal tentang tanaman/buah & materi sangat sedikit
RENCANA PELAKSANAAN PEMBELAJARAN HARIAN
kegiatan inti tidak nyambung dengan tujuan pembelajaran
kegiatan inti terdapat "Duniawi" ini maksudnya apa
TUJUAN PEMBELAJARAN
Tujuan pembelajaran kurang beriringan dengan CP STEAM
PEMAHAMAN BERMAKNA
PERTANYAAN PEMANTIK
RENCANA ASESMEN
HASIL PEMETAAN ASESMEN AWAL PESERTA DIDIK
RENCANA PELAKSANAAN PEMBELAJARAN
tidak ada materi, peta konsep, atp
INFORMASI UMUM
tidak ada materi, peta konsep, atp
KOMPONEN INTI
tidak ada materi
RPPH
menggunakan kurikulum 2013
tidak ada pembelajaran memanfaatkan buah asli
LANGKAH-LANGKAH KEGIATAN
tidak ada materi atp peta konsep
TUJUAN PEMBELAJARAN
tidak ada materi tfp
RENCANA PELAKSANAAN PEMBELAJARAN
tidak ada eksperimen tenatng pohon seperti yang ditulis di tp
PENILAIAN
tidak ada asesmen
IDENTITAS
tidak ada materi, peta konsep, atp, cp
PETA KONSEP
hanya 1, padahal untuk 6 hari
RENCANA KEGIATAN PEMBELAJARAN
kegiatan  tidak sesuai dengan tujuan kegiatan
CHEKLIST
CATATAN ANEKDOT
FOTO BERSERI
LEMBAR KEGIATAN ANAK
KOMPONEN INTI
tidak ada materi, atp
ASESMEN
tidak ada asesmen
"""

# Pisahkan teks menjadi kalimat-kalimat (menggunakan tanda baca sebagai pemisah)
text_list = re.split(r'\n+', output_text.strip())  # Menggunakan \n untuk memisahkan kalimat berdasarkan baris

# Gabungkan kalimat-kalimat menjadi satu string
full_text = ' '.join(text_list)

# Tokenisasi: Pisahkan teks menjadi kata-kata
words = re.findall(r'\b\w+\b', full_text.lower())  # .lower() untuk mengabaikan kapitalisasi

# Hitung frekuensi kemunculan kata
word_counts = Counter(words)

# Convert ke DataFrame untuk lebih mudah diproses dan ditampilkan
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Kata', 'Frekuensi'])

# Urutkan berdasarkan frekuensi terbanyak
word_counts_df = word_counts_df.sort_values(by='Frekuensi', ascending=False)

# Tampilkan tabel hasil
print("Tabel kata yang sering muncul:")
print(word_counts_df)

# Tampilkan bar chart dari kata yang sering muncul
plt.figure(figsize=(10, 5))
plt.bar(word_counts_df['Kata'][:15], word_counts_df['Frekuensi'][:15], color='skyblue')  # Menampilkan 15 kata teratas
plt.title('Top 15 Kata yang Sering Muncul')
plt.xlabel('Kata')
plt.ylabel('Frekuensi')
plt.xticks(rotation=45)
plt.show()

# Simpan hasil tabel ke file Excel (optional)
word_counts_df.to_excel("hasil_kata_sering_muncul.xlsx", index=False)
print("Tabel kata yang sering muncul telah disimpan sebagai 'hasil_kata_sering_muncul.xlsx'")
# Out:
# ...
# Tabel kata yang sering muncul:
#                      Kata  Frekuensi
# 5                   tidak         70
# 39                    ada         51
# 10           pembelajaran         50
# 18               kegiatan         45
# 33                 materi         30
# 44                    dan         27
# 2                 asesmen         26
# 9                  tujuan         21
# 60                 konsep         20
# 134                  peta         19
# 7                   hanya         15
# 63                rencana         14
# 103               langkah         14
# 29                 dengan         14
# 27                   inti         13
# 0                   hasil         13
# 96                peserta         12
# 40                    tfp         12
# 1                pemetaan         12
# 97                  didik         12
# 3                    awal         10
# 85            pelaksanaan          9
# 117             informasi          8
# ...

# %%
from google.colab import files
files.download('hasil_pengelompokan_kalimat.xlsx')

# %%
# Install library yang diperlukan
# !pip install pandas matplotlib

import pandas as pd
import re
from collections import Counter
import matplotlib.pyplot as plt

# Ambil output dari cell sebelumnya (misalnya, hasil output yang sudah ada)
output_text = """
HASIL PEMETAAN ASESMEN AWAL SISWA
tidak dipetakan, hanya kesimpulan
TUJUAN PEMBELAJARAN:
terdapat tujuan pembelajaran harian, apakah ini maksudnya ATP?
URUTAN KEGIATAN PEMBELAJARAN
terdapat muatan inovatif, P5 ditambahi kompetensi lain sendiri
tidak ada materi tfp
tidak optimal memanfaatkan buah asli untuk kegiatan
ASESMEN
tidak ada asesmen
LANGKAH LANGKAH KEGIATAN
tidak ada peta konsep, tidak ada materi tfp
ASESMEN
REFLEKSI
tidak ada asesmen dan refleksi
PETA KONSEP
hanya sebatas menyebutkan macam2 makanannya
RENCANA PELAKSANAAN PEMBELAJARAN
deskripsi umum kegiatan, pengembangan kegiatan dan kegiatan yang dilakukan tidak serasi
TARGET PESERTA DIDIK
terdapat Peserta didik dengan beda2 tingkatan, tapi tidak dijelaskan asesmen/bagaimana pendampingannya.
RENCANA PELAKSANAAN PEMBELAJARAN HARIAN
guru lebih banyak aktif
HASIL PEMETAAN ASESMEN AWAL PESERTA DIDIK
tidak ada pemetaannya
LANGKAH-LANGKAH PEMBELAJARAN
kegiatan tidak sesuai dengan tujuan kegiatan
PETA KONSEP
bangga daerah tapi subtopiknya tanaman
KOMPETENSI INTI
tidak ada materi dan tfp
IDENTITAS PROGRAM
identifikasi masalah pada siswa tidak sesuai dengan cp & tujuan pembelajaran
PETA KONSEP
hanya sub-sub judulnya
KEGIATAN HARIAN
tidak ada materi
RENCANA PELAKSANAAN PEMBELAJARAN
tidak ada materi, peta konsep, atp
INFORMASI UMUM
tidak ada materi, peta konsep, atp
KOMPONEN INTI
tidak ada materi
RPPH
menggunakan kurikulum 2013
tidak ada pembelajaran memanfaatkan buah asli
LANGKAH-LANGKAH KEGIATAN
tidak ada materi atp peta konsep
TUJUAN PEMBELAJARAN
tidak ada materi tfp
RENCANA PELAKSANAAN PEMBELAJARAN
tidak ada eksperimen tenatng pohon seperti yang ditulis di tp
PENILAIAN
tidak ada asesmen
IDENTITAS
tidak ada materi, peta konsep, atp, cp
PETA KONSEP
hanya 1, padahal untuk 6 hari
RENCANA KEGIATAN PEMBELAJARAN
kegiatan  tidak sesuai dengan tujuan kegiatan
CHEKLIST
CATATAN ANEKDOT
FOTO BERSERI
LEMBAR KEGIATAN ANAK
KOMPONEN INTI
tidak ada materi, atp
ASESMEN
tidak ada asesmen
"""

# Pisahkan teks menjadi kalimat-kalimat (menggunakan tanda baca sebagai pemisah)
text_list = re.split(r'\n+', output_text.strip())  # Menggunakan \n untuk memisahkan kalimat berdasarkan baris

# Gabungkan kalimat-kalimat menjadi satu string
full_text = ' '.join(text_list)

# Tokenisasi: Pisahkan teks menjadi kata-kata
words = re.findall(r'\b\w+\b', full_text.lower())  # .lower() untuk mengabaikan kapitalisasi

# Hitung frekuensi kemunculan kata
word_counts = Counter(words)

# Convert ke DataFrame untuk lebih mudah diproses dan ditampilkan
word_counts_df = pd.DataFrame(word_counts.items(), columns=['Kata', 'Frekuensi'])

# Urutkan berdasarkan frekuensi terbanyak
word_counts_df = word_counts_df.sort_values(by='Frekuensi', ascending=False)

# Tampilkan bar chart dari kata yang sering muncul
plt.figure(figsize=(12, 6))  # Menyesuaikan ukuran grafik agar lebih lebar
plt.bar(word_counts_df['Kata'][:15], word_counts_df['Frekuensi'][:15], color='skyblue')  # Menampilkan 15 kata teratas
plt.title('Top 15 Kata yang Sering Muncul')
plt.xlabel('Kata')
plt.ylabel('Frekuensi')
plt.xticks(rotation=45)
plt.show()
